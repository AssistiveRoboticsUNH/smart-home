# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
fn='/home/ns/smart_home_ws/src/smart-home/external/unity_pioneer/pioneer_navigation2/map/map.pgm'

# %%
org = cv2.imread(fn, cv2.IMREAD_GRAYSCALE)
im=org.copy()

# %%
plt.imshow(im, cmap='gray')

# %%
im
# Out:
# array([[205, 205, 205, ..., 205, 205, 205],
#        [205, 205, 205, ..., 205, 205, 205],
#        [205, 205, 205, ..., 205, 205, 205],
#        ...,
#        [205, 205, 205, ..., 254,   0, 205],
#        [205, 205, 205, ...,   0,   0, 205],
#        [205, 205, 205, ..., 205, 205, 205]], dtype=uint8)

# %%
set( im.tolist()[0] )
# Out:
# {0, 205}

# %%
# im[ np.where(im<=200) ]=0
# im[ np.where(im>200) ]=255

# %%
plt.imshow(im, cmap='gray')

# %%
ff=cv2.floodFill(im, None, (100,100), 120)

# %%
ff[0], ff[1].shape
# Out:
# (688, (178, 225))

# %%
plt.imshow(ff[1], cmap='gray')

# %%
floodval = 128
cv2.floodFill(im, None, (150,370), floodval)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In [6], line 2
#       1 floodval = 128
# ----> 2 cv2.floodFill(im, None, (150,370), floodval)
#
# error: OpenCV(4.5.4) ./modules/imgproc/src/floodfill.cpp:509: error: (-211:One of the arguments' values is out of range) Seed point is outside of image in function 'floodFill'

# %%
# Extract filled area alone
arena = ((im==floodval) * 255).astype(np.uint8)
